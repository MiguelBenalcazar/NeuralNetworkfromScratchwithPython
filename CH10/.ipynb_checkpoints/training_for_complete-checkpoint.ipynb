# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
import seaborn as sns
import matplotlib.pyplot as plt

nnfs.init()


# Dense layer
class Layer_Dense:

    # Layer initialization
    def __init__(self, n_inputs, n_neurons):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))

    # Forward pass
    def forward(self, inputs):
        # Remember input values
        self.inputs = inputs
        # Calculate output values from inputs, weights and biases
        self.output = np.dot(inputs, self.weights) + self.biases

    # Backward pass
    def backward(self, dvalues):
        # Gradients on parameters
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis=0, keepdims=True)
        # Gradient on values
        self.dinputs = np.dot(dvalues, self.weights.T)


# ReLU activation
class Activation_ReLU:

    # Forward pass
    def forward(self, inputs):

        # Remember input values
        self.inputs = inputs
        # Calculate output values from inputs
        self.output = np.maximum(0, inputs)

    # Backward pass
    def backward(self, dvalues):
        # Since we need to modify original variable,
        # let's make a copy of values first
        self.dinputs = dvalues.copy()

        # Zero gradient where input values were negative
        self.dinputs[self.inputs <= 0] = 0


# Softmax activation
class Activation_Softmax:

    # Forward pass
    def forward(self, inputs):
        # Remember input values
        self.inputs = inputs

        # Get unnormalized probabilities
        exp_values = np.exp(inputs - np.max(inputs, axis=1,
                                            keepdims=True))
        # Normalize them for each sample
        probabilities = exp_values / np.sum(exp_values, axis=1,
                                            keepdims=True)

        self.output = probabilities

    # Backward pass
    def backward(self, dvalues):

        # Create uninitialized array
        self.dinputs = np.empty_like(dvalues)

        # Enumerate outputs and gradients
        for index, (single_output, single_dvalues) in \
                enumerate(zip(self.output, dvalues)):
            # Flatten output array
            single_output = single_output.reshape(-1, 1)
            # Calculate Jacobian matrix of the output
            jacobian_matrix = np.diagflat(single_output) - \
                              np.dot(single_output, single_output.T)

            # Calculate sample-wise gradient
            # and add it to the array of sample gradients
            self.dinputs[index] = np.dot(jacobian_matrix,
                                         single_dvalues)


# Common loss class
class Loss:

    # Calculates the data and regularization losses
    # given model output and ground truth values
    def calculate(self, output, y):

        # Calculate sample losses
        sample_losses = self.forward(output, y)

        # Calculate mean loss
        data_loss = np.mean(sample_losses)

        # Return loss
        return data_loss


# Cross-entropy loss
class Loss_CategoricalCrossentropy(Loss):

    # Forward pass
    def forward(self, y_pred, y_true):

        # Number of samples in a batch
        samples = len(y_pred)

        # Clip data to prevent division by 0
        # Clip both sides to not drag mean towards any value
        y_pred_clipped = np.clip(y_pred, 1e-7, 1 - 1e-7)

        # Probabilities for target values -
        # only if categorical labels
        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[
                range(samples),
                y_true
            ]


        # Mask values - only for one-hot encoded labels
        elif len(y_true.shape) == 2:
            correct_confidences = np.sum(
                y_pred_clipped * y_true,
                axis=1
            )

        # Losses
        negative_log_likelihoods = -np.log(correct_confidences)
        return negative_log_likelihoods

    # Backward pass
    def backward(self, dvalues, y_true):

        # Number of samples
        samples = len(dvalues)
        # Number of labels in every sample
        # We'll use the first sample to count them
        labels = len(dvalues[0])

        # If labels are sparse, turn them into one-hot vector
        if len(y_true.shape) == 1:
            y_true = np.eye(labels)[y_true]

        # Calculate gradient
        self.dinputs = -y_true / dvalues
        # Normalize gradient
        self.dinputs = self.dinputs / samples


# Softmax classifier - combined Softmax activation
# and cross-entropy loss for faster backward step
class Activation_Softmax_Loss_CategoricalCrossentropy():

    # Creates activation and loss function objects
    def __init__(self):
        self.activation = Activation_Softmax()
        self.loss = Loss_CategoricalCrossentropy()

    # Forward pass
    def forward(self, inputs, y_true):
        # Output layer's activation function
        self.activation.forward(inputs)
        # Set the output
        self.output = self.activation.output
        # Calculate and return loss value
        return self.loss.calculate(self.output, y_true)


    # Backward pass
    def backward(self, dvalues, y_true):

        # Number of samples
        samples = len(dvalues)

        # If labels are one-hot encoded,
        # turn them into discrete values
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis=1)

        # Copy so we can safely modify
        self.dinputs = dvalues.copy()
        # Calculate gradient
        self.dinputs[range(samples), y_true] -= 1
        # Normalize gradient
        self.dinputs = self.dinputs / samples
        
class Optimizer_SGD:
    # Initialize optimizer - set settings,
    # learning rate of 1. is default for this optimizer
    def __init__(self, learning_rate=1.0):
        self.learning_rate = learning_rate
        
    # Update parameters
    def update_params(self, layer):
        layer.weights += -self.learning_rate * layer.dweights
        layer.biases += -self.learning_rate * layer.dbiases

# %%
# Create dataset
X, y = spiral_data(samples=100, classes=3)

# %%
# Create Dense layer with 2 input features and 64 output values
dense1 = Layer_Dense(2, 64)

# %%
# Create ReLU activation (to be used with Dense layer):
activation1 = Activation_ReLU()

# %%
# Create second Dense layer with 64 input features (as we take output
# of previous layer here) and 3 output values (output values)
dense2 = Layer_Dense(64, 3)

# %%
# Create Softmax classifier's combined loss and activation
loss_activation = Activation_Softmax_Loss_CategoricalCrossentropy()

# %%
# Create optimizer
optimizer = Optimizer_SGD(learning_rate=0.1)

# %%
loss_acum = []
accuracy_acum = []
count = []
y_hat = []

# Train in loop
for epoch in range(100001):
    # Perform a forward pass of our training data through this layer
    dense1.forward(X)
    
    # Perform a forward pass through activation function
    # takes the output of first dense layer here
    activation1.forward(dense1.output)
    
    # Perform a forward pass through second Dense layer
    # takes outputs of activation function of first layer as inputs
    dense2.forward(activation1.output)

    # Perform a forward pass through the activation/loss function
    # takes the output of second dense layer here and returns loss
    loss = loss_activation.forward(dense2.output, y)
    loss_acum.append(loss)
    
    # Calculate accuracy from output of activation2 and targets
    # calculate values along first axis
    predictions = np.argmax(loss_activation.output, axis=1)
    
    y_hat = predictions
    
    if len(y.shape) == 2:
        y = np.argmax(y, axis=1)
    accuracy = np.mean(predictions==y)
    accuracy_acum.append(accuracy)
    
    if not epoch % 100:
        print(f'epoch: {epoch}, ' +
              f'acc: {accuracy:.3f}, ' +
              f'loss: {loss:.3f}')
        
    # Backward pass
    loss_activation.backward(loss_activation.output, y)
    dense2.backward(loss_activation.dinputs)
    activation1.backward(dense2.dinputs)
    dense1.backward(activation1.dinputs)
    
    # Update weights and biases
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    count.append(epoch)
# Out:
# epoch: 0, acc: 0.873, loss: 0.360
# epoch: 100, acc: 0.537, loss: 2.475
# epoch: 200, acc: 0.607, loss: 5.005
# epoch: 300, acc: 0.513, loss: 2.458
# epoch: 400, acc: 0.590, loss: 2.966
# epoch: 500, acc: 0.617, loss: 3.848
# epoch: 600, acc: 0.550, loss: 2.830
# epoch: 700, acc: 0.770, loss: 0.629
# epoch: 800, acc: 0.713, loss: 0.678
# epoch: 900, acc: 0.617, loss: 1.066
# epoch: 1000, acc: 0.470, loss: 2.163
# epoch: 1100, acc: 0.747, loss: 0.628
# epoch: 1200, acc: 0.567, loss: 1.719
# epoch: 1300, acc: 0.513, loss: 1.651
# epoch: 1400, acc: 0.557, loss: 2.355
# epoch: 1500, acc: 0.467, loss: 1.776
# epoch: 1600, acc: 0.670, loss: 0.982
# epoch: 1700, acc: 0.553, loss: 2.266
# epoch: 1800, acc: 0.610, loss: 0.923
# epoch: 1900, acc: 0.597, loss: 1.711
# epoch: 2000, acc: 0.590, loss: 1.542
# epoch: 2100, acc: 0.567, loss: 1.747
# epoch: 2200, acc: 0.560, loss: 1.509
# epoch: 2300, acc: 0.643, loss: 0.827
# epoch: 2400, acc: 0.570, loss: 1.409
# epoch: 2500, acc: 0.590, loss: 1.843
# epoch: 2600, acc: 0.573, loss: 1.612
# epoch: 2700, acc: 0.587, loss: 1.510
# epoch: 2800, acc: 0.673, loss: 0.691
# epoch: 2900, acc: 0.717, loss: 0.645
# epoch: 3000, acc: 0.623, loss: 0.989
# epoch: 3100, acc: 0.503, loss: 1.504
# epoch: 3200, acc: 0.517, loss: 1.327
# epoch: 3300, acc: 0.530, loss: 1.449
# epoch: 3400, acc: 0.637, loss: 1.125
# epoch: 3500, acc: 0.597, loss: 1.431
# epoch: 3600, acc: 0.650, loss: 1.086
# epoch: 3700, acc: 0.570, loss: 1.313
# epoch: 3800, acc: 0.597, loss: 1.237
# epoch: 3900, acc: 0.597, loss: 1.157
# epoch: 4000, acc: 0.590, loss: 0.898
# epoch: 4100, acc: 0.540, loss: 1.434
# epoch: 4200, acc: 0.627, loss: 0.982
# epoch: 4300, acc: 0.517, loss: 1.705
# epoch: 4400, acc: 0.533, loss: 1.178
# epoch: 4500, acc: 0.623, loss: 1.319
# epoch: 4600, acc: 0.650, loss: 0.946
# epoch: 4700, acc: 0.603, loss: 1.186
# epoch: 4800, acc: 0.600, loss: 1.106
# epoch: 4900, acc: 0.610, loss: 0.807
# epoch: 5000, acc: 0.557, loss: 1.358
# epoch: 5100, acc: 0.640, loss: 0.869
# epoch: 5200, acc: 0.587, loss: 1.097
# epoch: 5300, acc: 0.607, loss: 1.073
# epoch: 5400, acc: 0.600, loss: 0.862
# epoch: 5500, acc: 0.637, loss: 0.800
# epoch: 5600, acc: 0.557, loss: 1.030
# epoch: 5700, acc: 0.620, loss: 1.129
# epoch: 5800, acc: 0.660, loss: 0.942
# epoch: 5900, acc: 0.603, loss: 1.078
# epoch: 6000, acc: 0.623, loss: 1.013
# epoch: 6100, acc: 0.630, loss: 0.946
# epoch: 6200, acc: 0.577, loss: 1.103
# epoch: 6300, acc: 0.557, loss: 0.991
# epoch: 6400, acc: 0.620, loss: 1.070
# epoch: 6500, acc: 0.670, loss: 0.890
# epoch: 6600, acc: 0.530, loss: 1.284
# epoch: 6700, acc: 0.570, loss: 0.953
# epoch: 6800, acc: 0.650, loss: 0.985
# epoch: 6900, acc: 0.670, loss: 0.897
# epoch: 7000, acc: 0.600, loss: 1.016
# epoch: 7100, acc: 0.613, loss: 0.863
# epoch: 7200, acc: 0.637, loss: 0.822
# epoch: 7300, acc: 0.643, loss: 0.795
# epoch: 7400, acc: 0.537, loss: 1.141
# epoch: 7500, acc: 0.547, loss: 0.975
# epoch: 7600, acc: 0.620, loss: 1.007
# epoch: 7700, acc: 0.670, loss: 0.845
# epoch: 7800, acc: 0.610, loss: 0.790
# epoch: 7900, acc: 0.547, loss: 1.026
# epoch: 8000, acc: 0.627, loss: 1.021
# epoch: 8100, acc: 0.673, loss: 0.813
# epoch: 8200, acc: 0.593, loss: 0.956
# epoch: 8300, acc: 0.620, loss: 0.962
# epoch: 8400, acc: 0.580, loss: 1.104
# epoch: 8500, acc: 0.640, loss: 0.782
# epoch: 8600, acc: 0.567, loss: 1.275
# epoch: 8700, acc: 0.547, loss: 0.990
# epoch: 8800, acc: 0.627, loss: 0.983
# epoch: 8900, acc: 0.680, loss: 0.785
# epoch: 9000, acc: 0.673, loss: 0.832
# epoch: 9100, acc: 0.610, loss: 0.967
# epoch: 9200, acc: 0.637, loss: 0.752
# epoch: 9300, acc: 0.643, loss: 0.843
# epoch: 9400, acc: 0.667, loss: 0.737
# epoch: 9500, acc: 0.537, loss: 1.064
# epoch: 9600, acc: 0.587, loss: 0.849
# epoch: 9700, acc: 0.653, loss: 0.931
# epoch: 9800, acc: 0.687, loss: 0.794
# epoch: 9900, acc: 0.603, loss: 0.974
# epoch: 10000, acc: 0.627, loss: 0.931
# epoch: 10100, acc: 0.580, loss: 1.075
# epoch: 10200, acc: 0.643, loss: 0.760
# epoch: 10300, acc: 0.530, loss: 1.240
# epoch: 10400, acc: 0.553, loss: 0.952
# epoch: 10500, acc: 0.623, loss: 0.964
# epoch: 10600, acc: 0.680, loss: 0.776
# epoch: 10700, acc: 0.660, loss: 0.862
# epoch: 10800, acc: 0.627, loss: 0.936
# epoch: 10900, acc: 0.640, loss: 0.727
# epoch: 11000, acc: 0.650, loss: 0.823
# epoch: 11100, acc: 0.667, loss: 0.726
# epoch: 11200, acc: 0.540, loss: 1.034
# epoch: 11300, acc: 0.590, loss: 0.849
# epoch: 11400, acc: 0.623, loss: 0.913
# epoch: 11500, acc: 0.683, loss: 0.773
# epoch: 11600, acc: 0.593, loss: 0.941
# epoch: 11700, acc: 0.630, loss: 0.926
# epoch: 11800, acc: 0.653, loss: 0.724
# epoch: 11900, acc: 0.653, loss: 0.813
# epoch: 12000, acc: 0.670, loss: 0.720
# epoch: 12100, acc: 0.540, loss: 1.086
# epoch: 12200, acc: 0.577, loss: 0.908
# epoch: 12300, acc: 0.633, loss: 0.936
# epoch: 12400, acc: 0.673, loss: 0.759
# epoch: 12500, acc: 0.680, loss: 0.790
# epoch: 12600, acc: 0.537, loss: 1.270
# epoch: 12700, acc: 0.560, loss: 0.972
# epoch: 12800, acc: 0.657, loss: 0.888
# epoch: 12900, acc: 0.640, loss: 0.809
# epoch: 13000, acc: 0.670, loss: 0.716
# epoch: 13100, acc: 0.530, loss: 1.123
# epoch: 13200, acc: 0.573, loss: 0.918
# epoch: 13300, acc: 0.670, loss: 0.821
# epoch: 13400, acc: 0.680, loss: 0.792
# epoch: 13500, acc: 0.627, loss: 0.918
# epoch: 13600, acc: 0.673, loss: 0.702
# epoch: 13700, acc: 0.673, loss: 0.708
# epoch: 13800, acc: 0.560, loss: 1.004
# epoch: 13900, acc: 0.667, loss: 0.831
# epoch: 14000, acc: 0.677, loss: 0.758
# epoch: 14100, acc: 0.610, loss: 0.931
# epoch: 14200, acc: 0.663, loss: 0.723
# epoch: 14300, acc: 0.663, loss: 0.718
# epoch: 14400, acc: 0.543, loss: 1.111
# epoch: 14500, acc: 0.687, loss: 0.698
# epoch: 14600, acc: 0.677, loss: 0.771
# epoch: 14700, acc: 0.590, loss: 0.970
# epoch: 14800, acc: 0.647, loss: 0.883
# epoch: 14900, acc: 0.673, loss: 0.698
# epoch: 15000, acc: 0.613, loss: 0.887
# epoch: 15100, acc: 0.580, loss: 0.886
# epoch: 15200, acc: 0.677, loss: 0.785
# epoch: 15300, acc: 0.667, loss: 0.830
# epoch: 15400, acc: 0.633, loss: 0.890
# epoch: 15500, acc: 0.673, loss: 0.695
# epoch: 15600, acc: 0.687, loss: 0.681
# epoch: 15700, acc: 0.570, loss: 0.923
# epoch: 15800, acc: 0.680, loss: 0.783
# epoch: 15900, acc: 0.673, loss: 0.801
# epoch: 16000, acc: 0.630, loss: 0.890
# epoch: 16100, acc: 0.677, loss: 0.692
# epoch: 16200, acc: 0.693, loss: 0.677
# epoch: 16300, acc: 0.573, loss: 0.944
# epoch: 16400, acc: 0.680, loss: 0.785
# epoch: 16500, acc: 0.683, loss: 0.769
# epoch: 16600, acc: 0.630, loss: 0.896
# epoch: 16700, acc: 0.680, loss: 0.691
# epoch: 16800, acc: 0.680, loss: 0.684
# epoch: 16900, acc: 0.563, loss: 0.985
# epoch: 17000, acc: 0.673, loss: 0.799
# epoch: 17100, acc: 0.683, loss: 0.751
# epoch: 17200, acc: 0.607, loss: 0.910
# epoch: 17300, acc: 0.660, loss: 0.723
# epoch: 17400, acc: 0.687, loss: 0.691
# epoch: 17500, acc: 0.547, loss: 1.104
# epoch: 17600, acc: 0.573, loss: 0.812
# epoch: 17700, acc: 0.683, loss: 0.765
# epoch: 17800, acc: 0.677, loss: 0.797
# epoch: 17900, acc: 0.637, loss: 0.884
# epoch: 18000, acc: 0.683, loss: 0.689
# epoch: 18100, acc: 0.687, loss: 0.684
# epoch: 18200, acc: 0.570, loss: 1.017
# epoch: 18300, acc: 0.673, loss: 0.729
# epoch: 18400, acc: 0.683, loss: 0.754
# epoch: 18500, acc: 0.617, loss: 0.935
# epoch: 18600, acc: 0.640, loss: 0.878
# epoch: 18700, acc: 0.687, loss: 0.688
# epoch: 18800, acc: 0.687, loss: 0.681
# epoch: 18900, acc: 0.570, loss: 1.026
# epoch: 19000, acc: 0.623, loss: 0.732
# epoch: 19100, acc: 0.683, loss: 0.756
# epoch: 19200, acc: 0.677, loss: 0.786
# epoch: 19300, acc: 0.633, loss: 0.880
# epoch: 19400, acc: 0.650, loss: 0.778
# epoch: 19500, acc: 0.683, loss: 0.684
# epoch: 19600, acc: 0.680, loss: 0.673
# epoch: 19700, acc: 0.667, loss: 0.773
# epoch: 19800, acc: 0.630, loss: 0.882
# epoch: 19900, acc: 0.650, loss: 0.813
# epoch: 20000, acc: 0.687, loss: 0.678
# epoch: 20100, acc: 0.693, loss: 0.687
# epoch: 20200, acc: 0.563, loss: 1.064
# epoch: 20300, acc: 0.587, loss: 0.932
# epoch: 20400, acc: 0.683, loss: 0.771
# epoch: 20500, acc: 0.687, loss: 0.742
# epoch: 20600, acc: 0.687, loss: 0.744
# epoch: 20700, acc: 0.630, loss: 0.891
# epoch: 20800, acc: 0.653, loss: 0.799
# epoch: 20900, acc: 0.683, loss: 0.680
# epoch: 21000, acc: 0.690, loss: 0.689
# epoch: 21100, acc: 0.563, loss: 1.199
# epoch: 21200, acc: 0.583, loss: 0.931
# epoch: 21300, acc: 0.680, loss: 0.774
# epoch: 21400, acc: 0.690, loss: 0.744
# epoch: 21500, acc: 0.690, loss: 0.701
# epoch: 21600, acc: 0.613, loss: 0.917
# epoch: 21700, acc: 0.643, loss: 0.868
# epoch: 21800, acc: 0.687, loss: 0.681
# epoch: 21900, acc: 0.690, loss: 0.674
# epoch: 22000, acc: 0.693, loss: 0.699
# epoch: 22100, acc: 0.567, loss: 1.072
# epoch: 22200, acc: 0.587, loss: 0.919
# epoch: 22300, acc: 0.687, loss: 0.760
# epoch: 22400, acc: 0.690, loss: 0.737
# epoch: 22500, acc: 0.597, loss: 0.966
# epoch: 22600, acc: 0.633, loss: 0.876
# epoch: 22700, acc: 0.680, loss: 0.685
# epoch: 22800, acc: 0.687, loss: 0.671
# epoch: 22900, acc: 0.690, loss: 0.712
# epoch: 23000, acc: 0.617, loss: 0.889
# epoch: 23100, acc: 0.660, loss: 0.841
# epoch: 23200, acc: 0.693, loss: 0.674
# epoch: 23300, acc: 0.700, loss: 0.668
# epoch: 23400, acc: 0.687, loss: 0.717
# epoch: 23500, acc: 0.567, loss: 1.066
# epoch: 23600, acc: 0.587, loss: 0.908
# epoch: 23700, acc: 0.687, loss: 0.754
# epoch: 23800, acc: 0.693, loss: 0.737
# epoch: 23900, acc: 0.613, loss: 0.903
# epoch: 24000, acc: 0.667, loss: 0.823
# epoch: 24100, acc: 0.687, loss: 0.679
# epoch: 24200, acc: 0.700, loss: 0.665
# epoch: 24300, acc: 0.690, loss: 0.690
# epoch: 24400, acc: 0.587, loss: 1.010
# epoch: 24500, acc: 0.597, loss: 0.794
# epoch: 24600, acc: 0.693, loss: 0.740
# epoch: 24700, acc: 0.693, loss: 0.735
# epoch: 24800, acc: 0.623, loss: 0.895
# epoch: 24900, acc: 0.667, loss: 0.740
# epoch: 25000, acc: 0.700, loss: 0.675
# epoch: 25100, acc: 0.693, loss: 0.674
# epoch: 25200, acc: 0.670, loss: 0.710
# epoch: 25300, acc: 0.587, loss: 0.969
# epoch: 25400, acc: 0.680, loss: 0.764
# epoch: 25500, acc: 0.693, loss: 0.732
# epoch: 25600, acc: 0.683, loss: 0.789
# epoch: 25700, acc: 0.647, loss: 0.876
# epoch: 25800, acc: 0.687, loss: 0.686
# epoch: 25900, acc: 0.693, loss: 0.668
# epoch: 26000, acc: 0.697, loss: 0.696
# epoch: 26100, acc: 0.563, loss: 1.182
# epoch: 26200, acc: 0.587, loss: 0.927
# epoch: 26300, acc: 0.693, loss: 0.743
# epoch: 26400, acc: 0.700, loss: 0.724
# epoch: 26500, acc: 0.707, loss: 0.673
# epoch: 26600, acc: 0.587, loss: 0.941
# epoch: 26700, acc: 0.650, loss: 0.865
# epoch: 26800, acc: 0.687, loss: 0.682
# epoch: 26900, acc: 0.693, loss: 0.661
# epoch: 27000, acc: 0.697, loss: 0.693
# epoch: 27100, acc: 0.623, loss: 0.885
# epoch: 27200, acc: 0.673, loss: 0.736
# epoch: 27300, acc: 0.700, loss: 0.667
# epoch: 27400, acc: 0.707, loss: 0.676
# epoch: 27500, acc: 0.560, loss: 1.288
# epoch: 27600, acc: 0.583, loss: 0.935
# epoch: 27700, acc: 0.693, loss: 0.748
# epoch: 27800, acc: 0.707, loss: 0.721
# epoch: 27900, acc: 0.710, loss: 0.675
# epoch: 28000, acc: 0.620, loss: 0.915
# epoch: 28100, acc: 0.647, loss: 0.849
# epoch: 28200, acc: 0.697, loss: 0.668
# epoch: 28300, acc: 0.700, loss: 0.658
# epoch: 28400, acc: 0.703, loss: 0.647
# epoch: 28500, acc: 0.593, loss: 0.967
# epoch: 28600, acc: 0.683, loss: 0.761
# epoch: 28700, acc: 0.707, loss: 0.718
# epoch: 28800, acc: 0.713, loss: 0.677
# epoch: 28900, acc: 0.583, loss: 0.971
# epoch: 29000, acc: 0.643, loss: 0.868
# epoch: 29100, acc: 0.677, loss: 0.693
# epoch: 29200, acc: 0.700, loss: 0.660
# epoch: 29300, acc: 0.703, loss: 0.673
# epoch: 29400, acc: 0.560, loss: 1.288
# epoch: 29500, acc: 0.590, loss: 0.934
# epoch: 29600, acc: 0.610, loss: 0.782
# epoch: 29700, acc: 0.707, loss: 0.723
# epoch: 29800, acc: 0.700, loss: 0.704
# epoch: 29900, acc: 0.700, loss: 0.716
# epoch: 30000, acc: 0.633, loss: 0.884
# epoch: 30100, acc: 0.677, loss: 0.711
# epoch: 30200, acc: 0.700, loss: 0.661
# epoch: 30300, acc: 0.703, loss: 0.670
# epoch: 30400, acc: 0.560, loss: 1.201
# epoch: 30500, acc: 0.590, loss: 0.907
# epoch: 30600, acc: 0.687, loss: 0.761
# epoch: 30700, acc: 0.707, loss: 0.718
# epoch: 30800, acc: 0.707, loss: 0.681
# epoch: 30900, acc: 0.583, loss: 0.975
# epoch: 31000, acc: 0.653, loss: 0.861
# epoch: 31100, acc: 0.683, loss: 0.696
# epoch: 31200, acc: 0.700, loss: 0.660
# epoch: 31300, acc: 0.707, loss: 0.667
# epoch: 31400, acc: 0.563, loss: 1.293
# epoch: 31500, acc: 0.590, loss: 0.902
# epoch: 31600, acc: 0.687, loss: 0.758
# epoch: 31700, acc: 0.707, loss: 0.712
# epoch: 31800, acc: 0.707, loss: 0.682
# epoch: 31900, acc: 0.580, loss: 1.005
# epoch: 32000, acc: 0.653, loss: 0.863
# epoch: 32100, acc: 0.683, loss: 0.694
# epoch: 32200, acc: 0.700, loss: 0.658
# epoch: 32300, acc: 0.707, loss: 0.670
# epoch: 32400, acc: 0.563, loss: 1.179
# epoch: 32500, acc: 0.590, loss: 0.870
# epoch: 32600, acc: 0.693, loss: 0.736
# epoch: 32700, acc: 0.713, loss: 0.711
# epoch: 32800, acc: 0.713, loss: 0.675
# epoch: 32900, acc: 0.607, loss: 0.936
# epoch: 33000, acc: 0.653, loss: 0.855
# epoch: 33100, acc: 0.697, loss: 0.678
# epoch: 33200, acc: 0.697, loss: 0.654
# epoch: 33300, acc: 0.707, loss: 0.669
# epoch: 33400, acc: 0.577, loss: 1.074
# epoch: 33500, acc: 0.593, loss: 0.897
# epoch: 33600, acc: 0.700, loss: 0.718
# epoch: 33700, acc: 0.713, loss: 0.706
# epoch: 33800, acc: 0.707, loss: 0.683
# epoch: 33900, acc: 0.630, loss: 0.903
# epoch: 34000, acc: 0.637, loss: 0.861
# epoch: 34100, acc: 0.697, loss: 0.668
# epoch: 34200, acc: 0.697, loss: 0.653
# epoch: 34300, acc: 0.700, loss: 0.643
# epoch: 34400, acc: 0.597, loss: 0.958
# epoch: 34500, acc: 0.653, loss: 0.704
# epoch: 34600, acc: 0.713, loss: 0.707
# epoch: 34700, acc: 0.707, loss: 0.684
# epoch: 34800, acc: 0.580, loss: 1.001
# epoch: 34900, acc: 0.653, loss: 0.860
# epoch: 35000, acc: 0.693, loss: 0.681
# epoch: 35100, acc: 0.697, loss: 0.655
# epoch: 35200, acc: 0.707, loss: 0.659
# epoch: 35300, acc: 0.580, loss: 1.047
# epoch: 35400, acc: 0.600, loss: 0.941
# epoch: 35500, acc: 0.703, loss: 0.709
# epoch: 35600, acc: 0.717, loss: 0.700
# epoch: 35700, acc: 0.720, loss: 0.688
# epoch: 35800, acc: 0.633, loss: 0.897
# epoch: 35900, acc: 0.687, loss: 0.710
# epoch: 36000, acc: 0.697, loss: 0.655
# epoch: 36100, acc: 0.707, loss: 0.670
# epoch: 36200, acc: 0.560, loss: 1.166
# epoch: 36300, acc: 0.590, loss: 0.885
# epoch: 36400, acc: 0.697, loss: 0.722
# epoch: 36500, acc: 0.717, loss: 0.705
# epoch: 36600, acc: 0.720, loss: 0.683
# epoch: 36700, acc: 0.630, loss: 0.911
# epoch: 36800, acc: 0.647, loss: 0.866
# epoch: 36900, acc: 0.697, loss: 0.671
# epoch: 37000, acc: 0.697, loss: 0.652
# epoch: 37100, acc: 0.693, loss: 0.645
# epoch: 37200, acc: 0.587, loss: 0.982
# epoch: 37300, acc: 0.607, loss: 0.942
# epoch: 37400, acc: 0.707, loss: 0.707
# epoch: 37500, acc: 0.713, loss: 0.694
# epoch: 37600, acc: 0.710, loss: 0.704
# epoch: 37700, acc: 0.637, loss: 0.894
# epoch: 37800, acc: 0.693, loss: 0.683
# epoch: 37900, acc: 0.700, loss: 0.654
# epoch: 38000, acc: 0.707, loss: 0.665
# epoch: 38100, acc: 0.567, loss: 1.098
# epoch: 38200, acc: 0.593, loss: 0.919
# epoch: 38300, acc: 0.707, loss: 0.707
# epoch: 38400, acc: 0.717, loss: 0.697
# epoch: 38500, acc: 0.713, loss: 0.698
# epoch: 38600, acc: 0.630, loss: 0.904
# epoch: 38700, acc: 0.650, loss: 0.851
# epoch: 38800, acc: 0.697, loss: 0.663
# epoch: 38900, acc: 0.700, loss: 0.651
# epoch: 39000, acc: 0.713, loss: 0.638
# epoch: 39100, acc: 0.597, loss: 0.956
# epoch: 39200, acc: 0.667, loss: 0.691
# epoch: 39300, acc: 0.710, loss: 0.701
# epoch: 39400, acc: 0.723, loss: 0.683
# epoch: 39500, acc: 0.713, loss: 0.707
# epoch: 39600, acc: 0.627, loss: 0.906
# epoch: 39700, acc: 0.680, loss: 0.815
# epoch: 39800, acc: 0.700, loss: 0.659
# epoch: 39900, acc: 0.707, loss: 0.656
# epoch: 40000, acc: 0.700, loss: 0.648
# epoch: 40100, acc: 0.597, loss: 0.949
# epoch: 40200, acc: 0.693, loss: 0.712
# epoch: 40300, acc: 0.717, loss: 0.699
# epoch: 40400, acc: 0.723, loss: 0.680
# epoch: 40500, acc: 0.593, loss: 0.980
# epoch: 40600, acc: 0.643, loss: 0.881
# epoch: 40700, acc: 0.690, loss: 0.690
# epoch: 40800, acc: 0.700, loss: 0.655
# epoch: 40900, acc: 0.707, loss: 0.653
# epoch: 41000, acc: 0.553, loss: 1.373
# epoch: 41100, acc: 0.587, loss: 0.927
# epoch: 41200, acc: 0.693, loss: 0.746
# epoch: 41300, acc: 0.717, loss: 0.698
# epoch: 41400, acc: 0.723, loss: 0.683
# epoch: 41500, acc: 0.727, loss: 0.675
# epoch: 41600, acc: 0.577, loss: 1.048
# epoch: 41700, acc: 0.587, loss: 0.956
# epoch: 41800, acc: 0.707, loss: 0.706
# epoch: 41900, acc: 0.717, loss: 0.693
# epoch: 42000, acc: 0.720, loss: 0.692
# epoch: 42100, acc: 0.617, loss: 0.938
# epoch: 42200, acc: 0.663, loss: 0.857
# epoch: 42300, acc: 0.700, loss: 0.664
# epoch: 42400, acc: 0.703, loss: 0.652
# epoch: 42500, acc: 0.710, loss: 0.635
# epoch: 42600, acc: 0.580, loss: 0.985
# epoch: 42700, acc: 0.597, loss: 0.945
# epoch: 42800, acc: 0.707, loss: 0.704
# epoch: 42900, acc: 0.727, loss: 0.689
# epoch: 43000, acc: 0.727, loss: 0.682
# epoch: 43100, acc: 0.710, loss: 0.700
# epoch: 43200, acc: 0.627, loss: 0.907
# epoch: 43300, acc: 0.637, loss: 0.875
# epoch: 43400, acc: 0.697, loss: 0.666
# epoch: 43500, acc: 0.700, loss: 0.650
# epoch: 43600, acc: 0.700, loss: 0.642
# epoch: 43700, acc: 0.573, loss: 1.051
# epoch: 43800, acc: 0.647, loss: 0.735
# epoch: 43900, acc: 0.710, loss: 0.694
# epoch: 44000, acc: 0.727, loss: 0.679
# epoch: 44100, acc: 0.700, loss: 0.755
# epoch: 44200, acc: 0.640, loss: 0.898
# epoch: 44300, acc: 0.690, loss: 0.790
# epoch: 44400, acc: 0.700, loss: 0.656
# epoch: 44500, acc: 0.703, loss: 0.651
# epoch: 44600, acc: 0.703, loss: 0.643
# epoch: 44700, acc: 0.567, loss: 1.018
# epoch: 44800, acc: 0.640, loss: 0.893
# epoch: 44900, acc: 0.683, loss: 0.739
# epoch: 45000, acc: 0.700, loss: 0.654
# epoch: 45100, acc: 0.703, loss: 0.650
# epoch: 45200, acc: 0.680, loss: 0.683
# epoch: 45300, acc: 0.593, loss: 0.953
# epoch: 45400, acc: 0.593, loss: 0.922
# epoch: 45500, acc: 0.707, loss: 0.704
# epoch: 45600, acc: 0.723, loss: 0.691
# epoch: 45700, acc: 0.720, loss: 0.694
# epoch: 45800, acc: 0.563, loss: 1.215
# epoch: 45900, acc: 0.590, loss: 0.884
# epoch: 46000, acc: 0.703, loss: 0.725
# epoch: 46100, acc: 0.717, loss: 0.703
# epoch: 46200, acc: 0.727, loss: 0.684
# epoch: 46300, acc: 0.600, loss: 0.990
# epoch: 46400, acc: 0.647, loss: 0.887
# epoch: 46500, acc: 0.703, loss: 0.667
# epoch: 46600, acc: 0.703, loss: 0.647
# epoch: 46700, acc: 0.703, loss: 0.642
# epoch: 46800, acc: 0.573, loss: 1.034
# epoch: 46900, acc: 0.590, loss: 0.969
# epoch: 47000, acc: 0.710, loss: 0.698
# epoch: 47100, acc: 0.723, loss: 0.690
# epoch: 47200, acc: 0.723, loss: 0.686
# epoch: 47300, acc: 0.617, loss: 0.951
# epoch: 47400, acc: 0.653, loss: 0.881
# epoch: 47500, acc: 0.700, loss: 0.673
# epoch: 47600, acc: 0.703, loss: 0.651
# epoch: 47700, acc: 0.703, loss: 0.648
# epoch: 47800, acc: 0.700, loss: 0.633
# epoch: 47900, acc: 0.570, loss: 1.035
# epoch: 48000, acc: 0.590, loss: 0.891
# epoch: 48100, acc: 0.710, loss: 0.691
# epoch: 48200, acc: 0.727, loss: 0.682
# epoch: 48300, acc: 0.710, loss: 0.708
# epoch: 48400, acc: 0.633, loss: 0.914
# epoch: 48500, acc: 0.693, loss: 0.683
# epoch: 48600, acc: 0.703, loss: 0.650
# epoch: 48700, acc: 0.703, loss: 0.652
# epoch: 48800, acc: 0.563, loss: 1.149
# epoch: 48900, acc: 0.590, loss: 0.895
# epoch: 49000, acc: 0.707, loss: 0.713
# epoch: 49100, acc: 0.720, loss: 0.699
# epoch: 49200, acc: 0.727, loss: 0.679
# epoch: 49300, acc: 0.597, loss: 0.985
# epoch: 49400, acc: 0.647, loss: 0.892
# epoch: 49500, acc: 0.690, loss: 0.671
# epoch: 49600, acc: 0.700, loss: 0.648
# epoch: 49700, acc: 0.703, loss: 0.650
# epoch: 49800, acc: 0.567, loss: 1.107
# epoch: 49900, acc: 0.617, loss: 0.842
# epoch: 50000, acc: 0.710, loss: 0.693
# epoch: 50100, acc: 0.727, loss: 0.681
# epoch: 50200, acc: 0.707, loss: 0.738
# epoch: 50300, acc: 0.637, loss: 0.907
# epoch: 50400, acc: 0.690, loss: 0.681
# epoch: 50500, acc: 0.697, loss: 0.650
# epoch: 50600, acc: 0.707, loss: 0.654
# epoch: 50700, acc: 0.563, loss: 1.188
# epoch: 50800, acc: 0.593, loss: 0.882
# epoch: 50900, acc: 0.710, loss: 0.695
# epoch: 51000, acc: 0.723, loss: 0.687
# epoch: 51100, acc: 0.720, loss: 0.693
# epoch: 51200, acc: 0.627, loss: 0.922
# epoch: 51300, acc: 0.640, loss: 0.884
# epoch: 51400, acc: 0.700, loss: 0.662
# epoch: 51500, acc: 0.703, loss: 0.649
# epoch: 51600, acc: 0.703, loss: 0.641
# epoch: 51700, acc: 0.577, loss: 1.077
# epoch: 51800, acc: 0.660, loss: 0.727
# epoch: 51900, acc: 0.717, loss: 0.691
# epoch: 52000, acc: 0.727, loss: 0.675
# epoch: 52100, acc: 0.600, loss: 0.999
# epoch: 52200, acc: 0.647, loss: 0.897
# epoch: 52300, acc: 0.693, loss: 0.670
# epoch: 52400, acc: 0.700, loss: 0.647
# epoch: 52500, acc: 0.703, loss: 0.651
# epoch: 52600, acc: 0.567, loss: 1.110
# epoch: 52700, acc: 0.620, loss: 0.821
# epoch: 52800, acc: 0.713, loss: 0.693
# epoch: 52900, acc: 0.727, loss: 0.680
# epoch: 53000, acc: 0.700, loss: 0.759
# epoch: 53100, acc: 0.643, loss: 0.908
# epoch: 53200, acc: 0.680, loss: 0.820
# epoch: 53300, acc: 0.700, loss: 0.659
# epoch: 53400, acc: 0.703, loss: 0.652
# epoch: 53500, acc: 0.700, loss: 0.636
# epoch: 53600, acc: 0.577, loss: 1.037
# epoch: 53700, acc: 0.700, loss: 0.715
# epoch: 53800, acc: 0.717, loss: 0.691
# epoch: 53900, acc: 0.723, loss: 0.670
# epoch: 54000, acc: 0.583, loss: 1.019
# epoch: 54100, acc: 0.657, loss: 0.891
# epoch: 54200, acc: 0.690, loss: 0.684
# epoch: 54300, acc: 0.700, loss: 0.652
# epoch: 54400, acc: 0.703, loss: 0.654
# epoch: 54500, acc: 0.550, loss: 1.341
# epoch: 54600, acc: 0.590, loss: 0.914
# epoch: 54700, acc: 0.710, loss: 0.688
# epoch: 54800, acc: 0.720, loss: 0.686
# epoch: 54900, acc: 0.720, loss: 0.696
# epoch: 55000, acc: 0.627, loss: 0.927
# epoch: 55100, acc: 0.700, loss: 0.737
# epoch: 55200, acc: 0.700, loss: 0.653
# epoch: 55300, acc: 0.707, loss: 0.655
# epoch: 55400, acc: 0.553, loss: 1.308
# epoch: 55500, acc: 0.590, loss: 0.908
# epoch: 55600, acc: 0.710, loss: 0.692
# epoch: 55700, acc: 0.727, loss: 0.686
# epoch: 55800, acc: 0.717, loss: 0.700
# epoch: 55900, acc: 0.627, loss: 0.924
# epoch: 56000, acc: 0.650, loss: 0.878
# epoch: 56100, acc: 0.700, loss: 0.663
# epoch: 56200, acc: 0.707, loss: 0.650
# epoch: 56300, acc: 0.703, loss: 0.641
# epoch: 56400, acc: 0.560, loss: 1.217
# epoch: 56500, acc: 0.597, loss: 0.888
# epoch: 56600, acc: 0.713, loss: 0.686
# epoch: 56700, acc: 0.720, loss: 0.686
# epoch: 56800, acc: 0.717, loss: 0.703
# epoch: 56900, acc: 0.627, loss: 0.927
# epoch: 57000, acc: 0.670, loss: 0.846
# epoch: 57100, acc: 0.700, loss: 0.657
# epoch: 57200, acc: 0.707, loss: 0.650
# epoch: 57300, acc: 0.700, loss: 0.636
# epoch: 57400, acc: 0.580, loss: 1.029
# epoch: 57500, acc: 0.707, loss: 0.721
# epoch: 57600, acc: 0.720, loss: 0.692
# epoch: 57700, acc: 0.727, loss: 0.666
# epoch: 57800, acc: 0.610, loss: 0.981
# epoch: 57900, acc: 0.657, loss: 0.887
# epoch: 58000, acc: 0.693, loss: 0.676
# epoch: 58100, acc: 0.697, loss: 0.651
# epoch: 58200, acc: 0.707, loss: 0.649
# epoch: 58300, acc: 0.707, loss: 0.641
# epoch: 58400, acc: 0.623, loss: 0.937
# epoch: 58500, acc: 0.640, loss: 0.894
# epoch: 58600, acc: 0.700, loss: 0.664
# epoch: 58700, acc: 0.700, loss: 0.645
# epoch: 58800, acc: 0.703, loss: 0.644
# epoch: 58900, acc: 0.567, loss: 1.109
# epoch: 59000, acc: 0.703, loss: 0.683
# epoch: 59100, acc: 0.717, loss: 0.689
# epoch: 59200, acc: 0.727, loss: 0.666
# epoch: 59300, acc: 0.587, loss: 1.025
# epoch: 59400, acc: 0.660, loss: 0.896
# epoch: 59500, acc: 0.700, loss: 0.664
# epoch: 59600, acc: 0.700, loss: 0.645
# epoch: 59700, acc: 0.697, loss: 0.638
# epoch: 59800, acc: 0.577, loss: 1.042
# epoch: 59900, acc: 0.703, loss: 0.730
# epoch: 60000, acc: 0.720, loss: 0.693
# epoch: 60100, acc: 0.727, loss: 0.669
# epoch: 60200, acc: 0.610, loss: 0.989
# epoch: 60300, acc: 0.657, loss: 0.889
# epoch: 60400, acc: 0.703, loss: 0.665
# epoch: 60500, acc: 0.700, loss: 0.643
# epoch: 60600, acc: 0.703, loss: 0.641
# epoch: 60700, acc: 0.573, loss: 1.062
# epoch: 60800, acc: 0.700, loss: 0.719
# epoch: 60900, acc: 0.720, loss: 0.693
# epoch: 61000, acc: 0.727, loss: 0.671
# epoch: 61100, acc: 0.583, loss: 1.034
# epoch: 61200, acc: 0.657, loss: 0.901
# epoch: 61300, acc: 0.700, loss: 0.665
# epoch: 61400, acc: 0.700, loss: 0.645
# epoch: 61500, acc: 0.703, loss: 0.640
# epoch: 61600, acc: 0.573, loss: 1.062
# epoch: 61700, acc: 0.660, loss: 0.728
# epoch: 61800, acc: 0.717, loss: 0.693
# epoch: 61900, acc: 0.727, loss: 0.678
# epoch: 62000, acc: 0.703, loss: 0.759
# epoch: 62100, acc: 0.637, loss: 0.915
# epoch: 62200, acc: 0.697, loss: 0.665
# epoch: 62300, acc: 0.700, loss: 0.646
# epoch: 62400, acc: 0.703, loss: 0.642
# epoch: 62500, acc: 0.573, loss: 1.054
# epoch: 62600, acc: 0.700, loss: 0.701
# epoch: 62700, acc: 0.720, loss: 0.693
# epoch: 62800, acc: 0.727, loss: 0.671
# epoch: 62900, acc: 0.590, loss: 1.014
# epoch: 63000, acc: 0.663, loss: 0.889
# epoch: 63100, acc: 0.700, loss: 0.661
# epoch: 63200, acc: 0.707, loss: 0.647
# epoch: 63300, acc: 0.713, loss: 0.635
# epoch: 63400, acc: 0.573, loss: 1.006
# epoch: 63500, acc: 0.707, loss: 0.707
# epoch: 63600, acc: 0.720, loss: 0.694
# epoch: 63700, acc: 0.727, loss: 0.674
# epoch: 63800, acc: 0.613, loss: 0.971
# epoch: 63900, acc: 0.670, loss: 0.865
# epoch: 64000, acc: 0.703, loss: 0.658
# epoch: 64100, acc: 0.700, loss: 0.650
# epoch: 64200, acc: 0.707, loss: 0.642
# epoch: 64300, acc: 0.570, loss: 0.989
# epoch: 64400, acc: 0.710, loss: 0.702
# epoch: 64500, acc: 0.723, loss: 0.694
# epoch: 64600, acc: 0.727, loss: 0.676
# epoch: 64700, acc: 0.613, loss: 0.967
# epoch: 64800, acc: 0.677, loss: 0.840
# epoch: 64900, acc: 0.703, loss: 0.655
# epoch: 65000, acc: 0.700, loss: 0.651
# epoch: 65100, acc: 0.690, loss: 0.666
# epoch: 65200, acc: 0.577, loss: 0.982
# epoch: 65300, acc: 0.710, loss: 0.699
# epoch: 65400, acc: 0.723, loss: 0.693
# epoch: 65500, acc: 0.727, loss: 0.677
# epoch: 65600, acc: 0.613, loss: 0.971
# epoch: 65700, acc: 0.670, loss: 0.852
# epoch: 65800, acc: 0.703, loss: 0.656
# epoch: 65900, acc: 0.703, loss: 0.647
# epoch: 66000, acc: 0.713, loss: 0.634
# epoch: 66100, acc: 0.573, loss: 1.018
# epoch: 66200, acc: 0.707, loss: 0.713
# epoch: 66300, acc: 0.727, loss: 0.693
# epoch: 66400, acc: 0.727, loss: 0.676
# epoch: 66500, acc: 0.597, loss: 1.017
# epoch: 66600, acc: 0.660, loss: 0.898
# epoch: 66700, acc: 0.700, loss: 0.662
# epoch: 66800, acc: 0.703, loss: 0.647
# epoch: 66900, acc: 0.700, loss: 0.636
# epoch: 67000, acc: 0.567, loss: 1.062
# epoch: 67100, acc: 0.703, loss: 0.702
# epoch: 67200, acc: 0.720, loss: 0.692
# epoch: 67300, acc: 0.730, loss: 0.673
# epoch: 67400, acc: 0.580, loss: 1.048
# epoch: 67500, acc: 0.653, loss: 0.906
# epoch: 67600, acc: 0.697, loss: 0.663
# epoch: 67700, acc: 0.703, loss: 0.647
# epoch: 67800, acc: 0.700, loss: 0.636
# epoch: 67900, acc: 0.570, loss: 1.062
# epoch: 68000, acc: 0.703, loss: 0.714
# epoch: 68100, acc: 0.720, loss: 0.693
# epoch: 68200, acc: 0.727, loss: 0.675
# epoch: 68300, acc: 0.593, loss: 1.030
# epoch: 68400, acc: 0.660, loss: 0.899
# epoch: 68500, acc: 0.697, loss: 0.663
# epoch: 68600, acc: 0.703, loss: 0.648
# epoch: 68700, acc: 0.703, loss: 0.634
# epoch: 68800, acc: 0.573, loss: 1.044
# epoch: 68900, acc: 0.707, loss: 0.724
# epoch: 69000, acc: 0.727, loss: 0.692
# epoch: 69100, acc: 0.727, loss: 0.673
# epoch: 69200, acc: 0.610, loss: 0.999
# epoch: 69300, acc: 0.667, loss: 0.885
# epoch: 69400, acc: 0.700, loss: 0.660
# epoch: 69500, acc: 0.703, loss: 0.649
# epoch: 69600, acc: 0.707, loss: 0.633
# epoch: 69700, acc: 0.570, loss: 1.029
# epoch: 69800, acc: 0.707, loss: 0.716
# epoch: 69900, acc: 0.727, loss: 0.692
# epoch: 70000, acc: 0.727, loss: 0.674
# epoch: 70100, acc: 0.610, loss: 0.999
# epoch: 70200, acc: 0.667, loss: 0.879
# epoch: 70300, acc: 0.703, loss: 0.659
# epoch: 70400, acc: 0.703, loss: 0.649
# epoch: 70500, acc: 0.707, loss: 0.633
# epoch: 70600, acc: 0.573, loss: 1.037
# epoch: 70700, acc: 0.707, loss: 0.715
# epoch: 70800, acc: 0.730, loss: 0.691
# epoch: 70900, acc: 0.727, loss: 0.674
# epoch: 71000, acc: 0.610, loss: 0.999
# epoch: 71100, acc: 0.660, loss: 0.887
# epoch: 71200, acc: 0.703, loss: 0.660
# epoch: 71300, acc: 0.703, loss: 0.648
# epoch: 71400, acc: 0.707, loss: 0.634
# epoch: 71500, acc: 0.577, loss: 1.049
# epoch: 71600, acc: 0.707, loss: 0.724
# epoch: 71700, acc: 0.730, loss: 0.692
# epoch: 71800, acc: 0.727, loss: 0.672
# epoch: 71900, acc: 0.600, loss: 1.015
# epoch: 72000, acc: 0.663, loss: 0.895
# epoch: 72100, acc: 0.703, loss: 0.661
# epoch: 72200, acc: 0.703, loss: 0.648
# epoch: 72300, acc: 0.707, loss: 0.634
# epoch: 72400, acc: 0.577, loss: 1.051
# epoch: 72500, acc: 0.703, loss: 0.728
# epoch: 72600, acc: 0.730, loss: 0.692
# epoch: 72700, acc: 0.727, loss: 0.673
# epoch: 72800, acc: 0.600, loss: 1.017
# epoch: 72900, acc: 0.660, loss: 0.896
# epoch: 73000, acc: 0.703, loss: 0.661
# epoch: 73100, acc: 0.703, loss: 0.650
# epoch: 73200, acc: 0.707, loss: 0.634
# epoch: 73300, acc: 0.573, loss: 1.050
# epoch: 73400, acc: 0.703, loss: 0.729
# epoch: 73500, acc: 0.727, loss: 0.694
# epoch: 73600, acc: 0.727, loss: 0.670
# epoch: 73700, acc: 0.597, loss: 1.024
# epoch: 73800, acc: 0.657, loss: 0.899
# epoch: 73900, acc: 0.700, loss: 0.658
# epoch: 74000, acc: 0.707, loss: 0.647
# epoch: 74100, acc: 0.703, loss: 0.638
# epoch: 74200, acc: 0.570, loss: 1.071
# epoch: 74300, acc: 0.707, loss: 0.697
# epoch: 74400, acc: 0.727, loss: 0.694
# epoch: 74500, acc: 0.727, loss: 0.673
# epoch: 74600, acc: 0.590, loss: 1.034
# epoch: 74700, acc: 0.637, loss: 0.924
# epoch: 74800, acc: 0.700, loss: 0.666
# epoch: 74900, acc: 0.700, loss: 0.649
# epoch: 75000, acc: 0.707, loss: 0.647
# epoch: 75100, acc: 0.563, loss: 1.168
# epoch: 75200, acc: 0.617, loss: 0.846
# epoch: 75300, acc: 0.720, loss: 0.689
# epoch: 75400, acc: 0.727, loss: 0.682
# epoch: 75500, acc: 0.720, loss: 0.703
# epoch: 75600, acc: 0.630, loss: 0.950
# epoch: 75700, acc: 0.693, loss: 0.691
# epoch: 75800, acc: 0.700, loss: 0.651
# epoch: 75900, acc: 0.700, loss: 0.651
# epoch: 76000, acc: 0.540, loss: 1.379
# epoch: 76100, acc: 0.597, loss: 0.962
# epoch: 76200, acc: 0.710, loss: 0.696
# epoch: 76300, acc: 0.727, loss: 0.688
# epoch: 76400, acc: 0.727, loss: 0.681
# epoch: 76500, acc: 0.613, loss: 0.987
# epoch: 76600, acc: 0.663, loss: 0.875
# epoch: 76700, acc: 0.700, loss: 0.658
# epoch: 76800, acc: 0.703, loss: 0.650
# epoch: 76900, acc: 0.703, loss: 0.635
# epoch: 77000, acc: 0.570, loss: 1.079
# epoch: 77100, acc: 0.710, loss: 0.643
# epoch: 77200, acc: 0.727, loss: 0.695
# epoch: 77300, acc: 0.727, loss: 0.680
# epoch: 77400, acc: 0.717, loss: 0.725
# epoch: 77500, acc: 0.623, loss: 0.943
# epoch: 77600, acc: 0.690, loss: 0.692
# epoch: 77700, acc: 0.700, loss: 0.651
# epoch: 77800, acc: 0.707, loss: 0.647
# epoch: 77900, acc: 0.697, loss: 0.647
# epoch: 78000, acc: 0.577, loss: 1.015
# epoch: 78100, acc: 0.707, loss: 0.717
# epoch: 78200, acc: 0.730, loss: 0.691
# epoch: 78300, acc: 0.727, loss: 0.677
# epoch: 78400, acc: 0.570, loss: 1.076
# epoch: 78500, acc: 0.637, loss: 0.926
# epoch: 78600, acc: 0.700, loss: 0.668
# epoch: 78700, acc: 0.700, loss: 0.650
# epoch: 78800, acc: 0.707, loss: 0.646
# epoch: 78900, acc: 0.557, loss: 1.338
# epoch: 79000, acc: 0.587, loss: 0.969
# epoch: 79100, acc: 0.710, loss: 0.697
# epoch: 79200, acc: 0.727, loss: 0.687
# epoch: 79300, acc: 0.730, loss: 0.679
# epoch: 79400, acc: 0.590, loss: 1.036
# epoch: 79500, acc: 0.647, loss: 0.918
# epoch: 79600, acc: 0.700, loss: 0.664
# epoch: 79700, acc: 0.703, loss: 0.650
# epoch: 79800, acc: 0.707, loss: 0.644
# epoch: 79900, acc: 0.563, loss: 1.212
# epoch: 80000, acc: 0.593, loss: 0.921
# epoch: 80100, acc: 0.707, loss: 0.730
# epoch: 80200, acc: 0.727, loss: 0.698
# epoch: 80300, acc: 0.727, loss: 0.684
# epoch: 80400, acc: 0.730, loss: 0.673
# epoch: 80500, acc: 0.730, loss: 0.674
# epoch: 80600, acc: 0.617, loss: 0.977
# epoch: 80700, acc: 0.657, loss: 0.898
# epoch: 80800, acc: 0.693, loss: 0.672
# epoch: 80900, acc: 0.697, loss: 0.650
# epoch: 81000, acc: 0.703, loss: 0.648
# epoch: 81100, acc: 0.710, loss: 0.681
# epoch: 81200, acc: 0.620, loss: 0.951
# epoch: 81300, acc: 0.673, loss: 0.839
# epoch: 81400, acc: 0.690, loss: 0.656
# epoch: 81500, acc: 0.703, loss: 0.651
# epoch: 81600, acc: 0.707, loss: 0.641
# epoch: 81700, acc: 0.610, loss: 0.981
# epoch: 81800, acc: 0.663, loss: 0.887
# epoch: 81900, acc: 0.693, loss: 0.661
# epoch: 82000, acc: 0.703, loss: 0.646
# epoch: 82100, acc: 0.703, loss: 0.641
# epoch: 82200, acc: 0.577, loss: 1.030
# epoch: 82300, acc: 0.640, loss: 0.919
# epoch: 82400, acc: 0.693, loss: 0.664
# epoch: 82500, acc: 0.700, loss: 0.648
# epoch: 82600, acc: 0.703, loss: 0.642
# epoch: 82700, acc: 0.563, loss: 1.244
# epoch: 82800, acc: 0.593, loss: 0.924
# epoch: 82900, acc: 0.717, loss: 0.696
# epoch: 83000, acc: 0.727, loss: 0.689
# epoch: 83100, acc: 0.727, loss: 0.682
# epoch: 83200, acc: 0.590, loss: 1.054
# epoch: 83300, acc: 0.647, loss: 0.924
# epoch: 83400, acc: 0.693, loss: 0.670
# epoch: 83500, acc: 0.700, loss: 0.651
# epoch: 83600, acc: 0.707, loss: 0.648
# epoch: 83700, acc: 0.693, loss: 0.662
# epoch: 83800, acc: 0.577, loss: 1.021
# epoch: 83900, acc: 0.700, loss: 0.735
# epoch: 84000, acc: 0.727, loss: 0.693
# epoch: 84100, acc: 0.727, loss: 0.678
# epoch: 84200, acc: 0.723, loss: 0.713
# epoch: 84300, acc: 0.623, loss: 0.961
# epoch: 84400, acc: 0.697, loss: 0.712
# epoch: 84500, acc: 0.700, loss: 0.655
# epoch: 84600, acc: 0.703, loss: 0.651
# epoch: 84700, acc: 0.703, loss: 0.635
# epoch: 84800, acc: 0.610, loss: 0.988
# epoch: 84900, acc: 0.667, loss: 0.882
# epoch: 85000, acc: 0.697, loss: 0.657
# epoch: 85100, acc: 0.703, loss: 0.646
# epoch: 85200, acc: 0.707, loss: 0.634
# epoch: 85300, acc: 0.573, loss: 1.069
# epoch: 85400, acc: 0.627, loss: 0.803
# epoch: 85500, acc: 0.720, loss: 0.700
# epoch: 85600, acc: 0.727, loss: 0.686
# epoch: 85700, acc: 0.730, loss: 0.688
# epoch: 85800, acc: 0.567, loss: 1.276
# epoch: 85900, acc: 0.597, loss: 0.932
# epoch: 86000, acc: 0.710, loss: 0.702
# epoch: 86100, acc: 0.730, loss: 0.687
# epoch: 86200, acc: 0.723, loss: 0.699
# epoch: 86300, acc: 0.620, loss: 0.974
# epoch: 86400, acc: 0.657, loss: 0.890
# epoch: 86500, acc: 0.697, loss: 0.673
# epoch: 86600, acc: 0.697, loss: 0.654
# epoch: 86700, acc: 0.707, loss: 0.651
# epoch: 86800, acc: 0.707, loss: 0.652
# epoch: 86900, acc: 0.527, loss: 1.517
# epoch: 87000, acc: 0.577, loss: 1.015
# epoch: 87100, acc: 0.613, loss: 0.845
# epoch: 87200, acc: 0.717, loss: 0.705
# epoch: 87300, acc: 0.727, loss: 0.690
# epoch: 87400, acc: 0.730, loss: 0.683
# epoch: 87500, acc: 0.723, loss: 0.701
# epoch: 87600, acc: 0.627, loss: 0.953
# epoch: 87700, acc: 0.630, loss: 0.923
# epoch: 87800, acc: 0.697, loss: 0.664
# epoch: 87900, acc: 0.697, loss: 0.651
# epoch: 88000, acc: 0.703, loss: 0.646
# epoch: 88100, acc: 0.703, loss: 0.650
# epoch: 88200, acc: 0.567, loss: 1.137
# epoch: 88300, acc: 0.597, loss: 0.889
# epoch: 88400, acc: 0.710, loss: 0.714
# epoch: 88500, acc: 0.727, loss: 0.700
# epoch: 88600, acc: 0.727, loss: 0.686
# epoch: 88700, acc: 0.730, loss: 0.672
# epoch: 88800, acc: 0.610, loss: 1.005
# epoch: 88900, acc: 0.650, loss: 0.918
# epoch: 89000, acc: 0.697, loss: 0.667
# epoch: 89100, acc: 0.700, loss: 0.650
# epoch: 89200, acc: 0.707, loss: 0.648
# epoch: 89300, acc: 0.713, loss: 0.660
# epoch: 89400, acc: 0.620, loss: 0.959
# epoch: 89500, acc: 0.697, loss: 0.754
# epoch: 89600, acc: 0.700, loss: 0.653
# epoch: 89700, acc: 0.703, loss: 0.652
# epoch: 89800, acc: 0.713, loss: 0.634
# epoch: 89900, acc: 0.577, loss: 1.049
# epoch: 90000, acc: 0.623, loss: 0.810
# epoch: 90100, acc: 0.720, loss: 0.706
# epoch: 90200, acc: 0.727, loss: 0.689
# epoch: 90300, acc: 0.730, loss: 0.682
# epoch: 90400, acc: 0.723, loss: 0.638
# epoch: 90500, acc: 0.617, loss: 0.982
# epoch: 90600, acc: 0.667, loss: 0.869
# epoch: 90700, acc: 0.697, loss: 0.653
# epoch: 90800, acc: 0.703, loss: 0.650
# epoch: 90900, acc: 0.707, loss: 0.634
# epoch: 91000, acc: 0.577, loss: 1.056
# epoch: 91100, acc: 0.600, loss: 0.887
# epoch: 91200, acc: 0.710, loss: 0.717
# epoch: 91300, acc: 0.727, loss: 0.703
# epoch: 91400, acc: 0.727, loss: 0.685
# epoch: 91500, acc: 0.723, loss: 0.700
# epoch: 91600, acc: 0.563, loss: 1.288
# epoch: 91700, acc: 0.597, loss: 0.941
# epoch: 91800, acc: 0.710, loss: 0.703
# epoch: 91900, acc: 0.727, loss: 0.694
# epoch: 92000, acc: 0.733, loss: 0.686
# epoch: 92100, acc: 0.597, loss: 1.037
# epoch: 92200, acc: 0.653, loss: 0.919
# epoch: 92300, acc: 0.697, loss: 0.669
# epoch: 92400, acc: 0.700, loss: 0.652
# epoch: 92500, acc: 0.707, loss: 0.650
# epoch: 92600, acc: 0.710, loss: 0.641
# epoch: 92700, acc: 0.617, loss: 0.983
# epoch: 92800, acc: 0.667, loss: 0.858
# epoch: 92900, acc: 0.697, loss: 0.656
# epoch: 93000, acc: 0.703, loss: 0.652
# epoch: 93100, acc: 0.713, loss: 0.634
# epoch: 93200, acc: 0.570, loss: 1.121
# epoch: 93300, acc: 0.600, loss: 0.909
# epoch: 93400, acc: 0.710, loss: 0.723
# epoch: 93500, acc: 0.727, loss: 0.705
# epoch: 93600, acc: 0.727, loss: 0.688
# epoch: 93700, acc: 0.727, loss: 0.698
# epoch: 93800, acc: 0.617, loss: 0.998
# epoch: 93900, acc: 0.657, loss: 0.910
# epoch: 94000, acc: 0.697, loss: 0.666
# epoch: 94100, acc: 0.700, loss: 0.653
# epoch: 94200, acc: 0.707, loss: 0.650
# epoch: 94300, acc: 0.707, loss: 0.646
# epoch: 94400, acc: 0.567, loss: 1.157
# epoch: 94500, acc: 0.597, loss: 0.944
# epoch: 94600, acc: 0.710, loss: 0.709
# epoch: 94700, acc: 0.727, loss: 0.699
# epoch: 94800, acc: 0.730, loss: 0.681
# epoch: 94900, acc: 0.730, loss: 0.660
# epoch: 95000, acc: 0.597, loss: 1.030
# epoch: 95100, acc: 0.647, loss: 0.927
# epoch: 95200, acc: 0.690, loss: 0.726
# epoch: 95300, acc: 0.697, loss: 0.658
# epoch: 95400, acc: 0.700, loss: 0.652
# epoch: 95500, acc: 0.703, loss: 0.653
# epoch: 95600, acc: 0.540, loss: 1.407
# epoch: 95700, acc: 0.590, loss: 0.982
# epoch: 95800, acc: 0.700, loss: 0.738
# epoch: 95900, acc: 0.727, loss: 0.702
# epoch: 96000, acc: 0.730, loss: 0.684
# epoch: 96100, acc: 0.727, loss: 0.672
# epoch: 96200, acc: 0.560, loss: 1.203
# epoch: 96300, acc: 0.600, loss: 0.923
# epoch: 96400, acc: 0.710, loss: 0.721
# epoch: 96500, acc: 0.720, loss: 0.707
# epoch: 96600, acc: 0.727, loss: 0.688
# epoch: 96700, acc: 0.723, loss: 0.708
# epoch: 96800, acc: 0.627, loss: 0.965
# epoch: 96900, acc: 0.697, loss: 0.763
# epoch: 97000, acc: 0.697, loss: 0.657
# epoch: 97100, acc: 0.703, loss: 0.651
# epoch: 97200, acc: 0.707, loss: 0.638
# epoch: 97300, acc: 0.557, loss: 1.136
# epoch: 97400, acc: 0.597, loss: 0.902
# epoch: 97500, acc: 0.717, loss: 0.699
# epoch: 97600, acc: 0.727, loss: 0.688
# epoch: 97700, acc: 0.730, loss: 0.680
# epoch: 97800, acc: 0.607, loss: 1.029
# epoch: 97900, acc: 0.650, loss: 0.926
# epoch: 98000, acc: 0.697, loss: 0.668
# epoch: 98100, acc: 0.703, loss: 0.654
# epoch: 98200, acc: 0.703, loss: 0.653
# epoch: 98300, acc: 0.547, loss: 1.422
# epoch: 98400, acc: 0.597, loss: 0.977
# epoch: 98500, acc: 0.707, loss: 0.719
# epoch: 98600, acc: 0.727, loss: 0.698
# epoch: 98700, acc: 0.730, loss: 0.680
# epoch: 98800, acc: 0.727, loss: 0.697
# epoch: 98900, acc: 0.623, loss: 0.983
# epoch: 99000, acc: 0.663, loss: 0.869
# epoch: 99100, acc: 0.697, loss: 0.659
# epoch: 99200, acc: 0.700, loss: 0.651
# epoch: 99300, acc: 0.703, loss: 0.647
# epoch: 99400, acc: 0.553, loss: 1.203
# epoch: 99500, acc: 0.597, loss: 0.957
# epoch: 99600, acc: 0.710, loss: 0.704
# epoch: 99700, acc: 0.727, loss: 0.692
# epoch: 99800, acc: 0.727, loss: 0.675
# epoch: 99900, acc: 0.573, loss: 1.105
# epoch: 100000, acc: 0.647, loss: 0.935

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y_hat)

# %%
sns.lineplot(y=loss_acum, x=count)
plt.ylim(0, 5)
# Out:
# (0.0, 5.0)

# %%
sns.lineplot(y=accuracy_acum , x=count)
plt.ylim(0.3, 0.8)
# Out:
# (0.3, 0.8)
